# %% [markdown]
# <a href="https://colab.research.google.com/github/noahgift/intermittent-fasting/blob/master/intermittent_fasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Approximately 10 Years of Bodyweight

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/noahgift/intermittent-fasting/master/weight.csv")
df.head()
# Out:
#          Date  Weight (lb)
# 0  12/22/2019        222.9
# 1  12/18/2019        222.0
# 2  12/15/2019        222.2
# 3   12/7/2019        219.3
# 4   12/1/2019        220.4

# %% [markdown]
# Create datetime index

# %%
df['Datetime'] = pd.to_datetime(df['Date'])
df = df.set_index('Datetime')
df = df.drop(['Date'], axis=1)
df.head()
# Out:
#             Weight (lb)
# Datetime
# 2019-12-22        222.9
# 2019-12-18        222.0
# 2019-12-15        222.2
# 2019-12-07        219.3
# 2019-12-01        220.4

# %%
df.columns
# Out:
# Index(['Weight (lb)'], dtype='object')

# %% [markdown]
# ### Descriptive Statistics

# %%
df.describe()
# Out:
#        Weight (lb)
# count  1013.000000
# mean    225.407601
# std       4.813612
# min     213.400000
# 25%     221.900000
# 50%     224.400000
# 75%     228.000000
# max     245.200000

# %%
sns.boxplot(x=df["Weight (lb)"], color="green")

# %%
sns.distplot(df["Weight (lb)"], color="red")

# %% [markdown]
# ### Time Series Plot

# %%
g = sns.relplot(data=df, kind="line", ci=68)
g.fig.set_size_inches(35,6)
g.set_titles("Body Weight 2011-2019")
